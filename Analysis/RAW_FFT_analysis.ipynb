# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
filename = '220629test.xlsx'
df = pd.read_excel(filename, usecols='C:F', engine='openpyxl')

# %%
TIME = df['time'].tolist()
ACC_X = df['acc_x'].tolist()
ACC_Y = df['acc_y'].tolist()
ACC_Z = df['acc_z'].tolist()

# %%
ABS_ACC = []
length = len(ACC_X)
for i in range(length):
    ABS_ACC[i] = math.sqrt(pow(ACC_X[i],2)+pow(ACC_Y[i],2)+pow(ACC_Z[i],2))

# %%
fft=[[0]*length]#*3
fft_magnitude = [[0]*length]#*3
fft[0] = np.fft.fft(ABS_ACC) / length

fft_magnitude = abs(fft)

# %%
plt.figure(figsize=(30,18))
plt.subplot(3,1,1)
plt.plot(TIME, SQRT_ACC_1)
plt.grid(True)
plt.subplot(3,1,2)
plt.plot(TIME, SQRT_ANG_1)
plt.grid(True)
plt.subplot(3,1,3)
plt.plot(TIME, SQRT_AV_1)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show>
